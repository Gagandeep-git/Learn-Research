# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
master = pd.read_csv("CarPrice_Assignment.csv", encoding = "ISO-8859-1")

# %%
master.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase   ...     enginesize  \
# 0  convertible        rwd          front       88.6   ...            130
# 1  convertible        rwd          front       88.6   ...            130
# 2    hatchback        rwd          front       94.5   ...            152
# 3        sedan        fwd          front       99.8   ...            109
# 4        sedan        4wd          front       99.4   ...            136
#
# ...

# %%
master.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# inspect the structure etc.
print(master.info(), "\n")
print(master.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# car_ID              205 non-null int64
# symboling           205 non-null int64
# CarName             205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# ...

# %%
# missing values in master df
master.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
column_list = master.columns.values.tolist()
column_list
# Out:
# ['car_ID',
#  'symboling',
#  'CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginetype',
#  'cylindernumber',
#  'enginesize',
#  'fuelsystem',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
len(np.unique(master['car_ID'], axis=0))
# Out:
# 205

# %%
len(np.unique(master['car_ID'], axis=0))
# Out:
# 205

# %%
# consider only company name as the independent variable for model building
# We need to extract the first word from CarName attribute.
company_carname_split=master['CarName'].str.split(" ", expand=True)
master=master.assign(carCompany=company_carname_split[0])

# %%
master.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase     ...       fuelsystem  \
# 0  convertible        rwd          front       88.6     ...             mpfi
# 1  convertible        rwd          front       88.6     ...             mpfi
# 2    hatchback        rwd          front       94.5     ...             mpfi
# 3        sedan        fwd          front       99.8     ...             mpfi
# 4        sedan        4wd          front       99.4     ...             mpfi
#
# ...

# %%
# have a look at all the company names
master.carCompany.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
# converting all company names to small case for homogeneity
master.carCompany=master.carCompany.apply(lambda x:x.lower())

# %%
# have a look at all the company names
master.carCompany.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
# create a copy of master df
master_copy2=master

# %%
# some company names are coming twice due to spelling mistakes
# Let's correct spelling 
master=master.replace('maxda','mazda')
master=master.replace('porcshce','porsche')
master=master.replace('toyouta','toyota')
master=master.replace('vokswagen','volkswagen')
master=master.replace('vw','volkswagen')

# %%
# have a look at all the company names
master.carCompany.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
# check for duplicate rows
master["is_duplicate"]= master.duplicated()

# %%
master.is_duplicate.unique()
# Out:
# array([False])

# %%
# that means no duplicate rows

# %%
# identify primary key for the master df
print(master.shape, "\n")
master.nunique()           # finds the number of unique values for each attribute (column) of the master dataframe
# Out:
# (205, 28)
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# carCompany           22
# is_duplicate          1
# dtype: int64

# %%
# the number of entries (values) for the variable car_ID is same as the number of rows in the dataframe
# this means we can consider car_ID as the primary key

# %%
master.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# lets check for missing values in master df once again
master.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# carCompany          0
# is_duplicate        0
# dtype: int64

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 28 columns):
# car_ID              205 non-null int64
# symboling           205 non-null int64
# CarName             205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# ...

# %%
master.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase      ...       boreratio  \
# 0  convertible        rwd          front       88.6      ...            3.47
# 1  convertible        rwd          front       88.6      ...            3.47
# 2    hatchback        rwd          front       94.5      ...            2.68
# 3        sedan        fwd          front       99.8      ...            3.19
# 4        sedan        4wd          front       99.4      ...            3.19
#
# ...

# %%
# we do not need the 'is_duplicate' column anymore .. lets drop it
master_copy3=master

# %%
master=master.drop('is_duplicate',axis=1)

# %%
print(master.dtypes)
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# carCompany           object
# dtype: object

# %%
# have a look at all the columns and check if the ranges are within the values provided in the source page :
# https://archive.ics.uci.edu/ml/datasets/Automobile
master.carbody.unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
master.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# comparing all the numeric values with the range of given in the source page, the values are within the given range

# %%
# lets compare non numeric values
# lets see what columns are non numeric

# %%
master.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# carCompany           object
# dtype: object

# %%
# this will display non numeric attributes
#master_non_numeric=master.select_dtypes(exclude=['int64','float64'])

# %%
# lets check the values of each of these attributes one by one .. no need to check CarName- we will drop it
print(master.fueltype.unique(),"\n")
# Out:
# ['gas' 'diesel']

# %%
print(master.aspiration.unique(),"\n")
# Out:
# ['std' 'turbo']

# %%
print(master.doornumber.unique(),"\n")
# Out:
# ['two' 'four']

# %%
print(master.carbody.unique(),"\n")
# Out:
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']

# %%
print(master.drivewheel.unique(),"\n")
# Out:
# ['rwd' 'fwd' '4wd']

# %%
print(master.enginelocation.unique(),"\n")
# Out:
# ['front' 'rear']

# %%
print(master.enginetype.unique(),"\n")
# Out:
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']

# %%
print(master.cylindernumber.unique(),"\n")
# Out:
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']

# %%
print(master.fuelsystem.unique(),"\n")
# Out:
# ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']

# %%
print(master.carCompany.unique(),"\n")
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'buick' 'mercury' 'mitsubishi' 'nissan' 'peugeot' 'plymouth'
#  'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen' 'volvo']

# %%
# correct spellig of 'peugeot' to 'peugot' as per the source webpage
master=master.replace('peugeot','peugot')

# %%
print(master.carCompany.unique(),"\n")
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'buick' 'mercury' 'mitsubishi' 'nissan' 'peugot' 'plymouth'
#  'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen' 'volvo']

# %%
# 'buick' company name is not present in source.. Therefore, removing the rows corresponding to buick company
# keep a copy of master
master_copy4=master

# %%
master=master[master['carCompany']!='buick']

# %%
# drop carName as only carCompany is an independent variable for model creation
master=master.drop('CarName',axis=1)

# %%
master.shape
# Out:
# (197, 26)

# %%
#### DATA CLEANING ENDS ####


master_clean_copy=master

# %%
print(len(master.carCompany.unique()),"\n")
# Out:
# 21

# %%
# Understanding the data

# %%
# Let's make some plots
# First let's see which variables have higher correlations/ associations with price (output variable) using heat map
master.shape
# Out:
# (197, 26)

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197 entries, 0 to 204
# Data columns (total 26 columns):
# car_ID              197 non-null int64
# symboling           197 non-null int64
# fueltype            197 non-null object
# aspiration          197 non-null object
# doornumber          197 non-null object
# carbody             197 non-null object
# drivewheel          197 non-null object
# enginelocation      197 non-null object
# wheelbase           197 non-null float64
# carlength           197 non-null float64
# carwidth            197 non-null float64
# carheight           197 non-null float64
# curbweight          197 non-null int64
# enginetype          197 non-null object
# cylindernumber      197 non-null object
# enginesize          197 non-null int64
# fuelsystem          197 non-null object
# boreratio           197 non-null float64
# stroke              197 non-null float64
# compressionratio    197 non-null float64
# horsepower          197 non-null int64
# ...

# %%
# the dataframe has many variables including categorical variables
# first let's check numeric variables

# %%
# let's make scatter plots of each of the numeric variables with price
# numeric variables to be checked
numeric_vars= master.iloc[:, (np.where((master.dtypes == np.int64) | (master.dtypes == np.float64)))[0]].columns
numeric_vars
# Out:
# Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.wheelbase, master.price)

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.carlength, master.price)

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.carwidth, master.price)

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.carheight, master.price)

# %%
# the relationship between carheight and price is not very clear

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.curbweight, master.price)

# %%
# looks like we can fit a straight line for this relationship

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.enginesize, master.price)

# %%
# looks like we can fit a straight line for this relationship

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.boreratio, master.price)

# %%
# again the above relationship is not very clear

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.stroke, master.price)

# %%
# again the above relationship is not very clear

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.compressionratio, master.price)

# %%
# not a linear relationship looks more like some classification problem

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.horsepower, master.price)

# %%
# looks like we can fit a straight line for this relationship

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.peakrpm, master.price)

# %%
# again the above relationship is not very clear

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.citympg, master.price)

# %%
# looks like citympeg has negative correlation with price, though the relationship looks somewhat linear

# %%
plt.figure(figsize=[6,6])
plt.scatter(master.highwaympg, master.price)

# %%
# looks like highwaympeg has negative correlation with price, though the relationship looks somewhat linear

# %%
# Understanding categorical data

# %%
# based on the above scatter plots good numeric features to begin a model : enginesize, horsepower, curbweight, citympg, highwaympg

# %%
# ################# BOX PLOTS FOR CATEGORICAL DATA   ###############

# %%
sns.boxplot(x='symboling', y='price', data=master)

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='carCompany', y='price', data=master)

# %%
# for certain companies price is higher
# Jaguar and porsche have higher median price
# There are a number of car companies having median price less than 10000

# %%
# looking at the box plot, let us focus on the boxes (25th to 75th percentile)
# we can divide the car companies into two categories - high_price_company and low_price_company
# we will do this later when we handle categorical data

# %%
# let us check the relationship of carCompany with horsepower, and enginesize

# %%
# box plot of carCompany vs horsepower
plt.figure(figsize=(20,10))
sns.boxplot(x='carCompany', y='horsepower', data=master)

# %%
# box plot of carCompany vs enginesize
plt.figure(figsize=(20,10))
sns.boxplot(x='carCompany', y='enginesize', data=master)

# %%
# box plot of carCompany vs enginesize
plt.figure(figsize=(20,10))
sns.boxplot(x='carCompany', y='curbweight', data=master)

# %%
# box plot of carCompany vs enginesize
plt.figure(figsize=(20,10))
sns.boxplot(x='carCompany', y='highwaympg', data=master)

# %%
# box plot of carCompany vs enginesize
plt.figure(figsize=(20,10))
sns.boxplot(x='carCompany', y='citympg', data=master)

# %%
# relationship of carCompany with enginesize, horsepower, curbweight is similar to its relationship with price
# this further indicates that we can categorise carCompany variable into two categories based on its relationship with price
# we will come to this later while handling categorical variables

# %%
# however the relationship of carCompany with citympg, highwaympg seems to follow a different trend .. bmw, jaguar and porsche lie
# on the lower half of the plot, somewhat expect as the relationship between each of these variables with price is negative one
# However, the relationship of carCompany with citympg, highwaympg is not as crisp as its relationship with enginsize,
# curbweight and horsepower

# %%
sns.boxplot(x='fueltype', y='price', data=master)

# %%
# median price of diesel cars is higher

# %%
sns.boxplot(x='aspiration', y='price', data=master)

# %%
# median price of turbo aspiration is higher

# %%
sns.boxplot(x='doornumber', y='price', data=master)

# %%
# median price of a four door car is higher than a two door car.. This is quite expected

# %%
sns.boxplot(x='carbody', y='price', data=master)

# %%
# # median price of hatchback is lowest.. Median price of convertible is highest. Apart from convertible , most companies shown
# above have overlap in prices of cars

# %%
sns.boxplot(x='drivewheel', y='price', data=master)

# %%
# median price of rwd drivewheel is higher than other two. fwd and 4wd have some overlap in price

# %%
sns.boxplot(x='enginelocation', y='price', data=master)

# %%
# companies that make rear engine sell higher than front engine companies

# %%
sns.boxplot(x='enginetype', y='price', data=master)

# %%
# median price of ohcv enginetype is highest

# %%
sns.boxplot(x='cylindernumber', y='price', data=master)

# %%
# median price of six cylinder type is highest

# %%
sns.boxplot(x='fuelsystem', y='price', data=master)

# %%
############## HANDLING CATEGORICAL DATA ######################

# %%
# box plot of carCompany vs enginesize and carCompany vs horsepower has similarity to carCompany vs price.
# Therefore, we create two categories for carCompany - high_price_comapny and low_price_company

# %%
# lists of variable values to map
high_price_company_list=['bmw', 'jaguar', 'porsche']
high_price_company_list
# Out:
# ['bmw', 'jaguar', 'porsche']

# %%
low_price_company_list = list(set(master.carCompany.unique())- set(high_price_company_list))
len(low_price_company_list)
# Out:
# 18

# %%
master_copy5=master

# %%
company_dictionary = { i : 'high_price_company' for i in high_price_company_list }
company_dictionary
# Out:
# {'bmw': 'high_price_company',
#  'jaguar': 'high_price_company',
#  'porsche': 'high_price_company'}

# %%
company_dictionary_low={ j : 'low_price_company' for j in low_price_company_list }
company_dictionary_low
# Out:
# {'plymouth': 'low_price_company',
#  'honda': 'low_price_company',
#  'volvo': 'low_price_company',
#  'alfa-romero': 'low_price_company',
#  'renault': 'low_price_company',
#  'saab': 'low_price_company',
#  'mitsubishi': 'low_price_company',
#  'dodge': 'low_price_company',
#  'mercury': 'low_price_company',
#  'toyota': 'low_price_company',
#  'mazda': 'low_price_company',
#  'subaru': 'low_price_company',
#  'nissan': 'low_price_company',
#  'audi': 'low_price_company',
#  'chevrolet': 'low_price_company',
#  'isuzu': 'low_price_company',
#  'peugot': 'low_price_company',
#  'volkswagen': 'low_price_company'}

# %%
company_dictionary.update(company_dictionary_low)
company_dictionary
# Out:
# {'bmw': 'high_price_company',
#  'jaguar': 'high_price_company',
#  'porsche': 'high_price_company',
#  'plymouth': 'low_price_company',
#  'honda': 'low_price_company',
#  'volvo': 'low_price_company',
#  'alfa-romero': 'low_price_company',
#  'renault': 'low_price_company',
#  'saab': 'low_price_company',
#  'mitsubishi': 'low_price_company',
#  'dodge': 'low_price_company',
#  'mercury': 'low_price_company',
#  'toyota': 'low_price_company',
#  'mazda': 'low_price_company',
#  'subaru': 'low_price_company',
#  'nissan': 'low_price_company',
#  'audi': 'low_price_company',
#  'chevrolet': 'low_price_company',
#  'isuzu': 'low_price_company',
#  'peugot': 'low_price_company',
#  'volkswagen': 'low_price_company'}

# %%
master['companyType'] = master['carCompany'].map(company_dictionary)

# %%
master.head(13)
# Out:
#     car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0        1          3      gas        std        two  convertible        rwd
# 1        2          3      gas        std        two  convertible        rwd
# 2        3          1      gas        std        two    hatchback        rwd
# 3        4          2      gas        std       four        sedan        fwd
# 4        5          2      gas        std       four        sedan        4wd
# 5        6          2      gas        std        two        sedan        fwd
# 6        7          1      gas        std       four        sedan        fwd
# 7        8          1      gas        std       four        wagon        fwd
# 8        9          1      gas      turbo       four        sedan        fwd
# 9       10          0      gas      turbo        two    hatchback        4wd
# 10      11          2      gas        std        two        sedan        rwd
# ...

# %%
# lets create dummy encoding for the categorical variable companyType 
# that has two levels : low_price_company and high_price_company

# %%
master_copy6=master

# %%
companyTypes = pd.get_dummies(master['companyType'], drop_first=True)
master=pd.concat([master, companyTypes], axis=1)

# %%
# Handling other categorical variables
# fueltype,aspiration,doornumber,carbody, drivewheel, enginelocation, enginetype, cylindernumber, fuelsystem,symboling

# %%
master.fueltype.unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
master.aspiration.unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
master.doornumber.unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
master.carbody.unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
master.drivewheel.unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
master.enginelocation.unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
master.enginetype.unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
master.cylindernumber.unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
master.fuelsystem.unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
master.symboling.unique()
# Out:
# array([ 3,  1,  2,  0, -1, -2], dtype=int64)

# %%
#doornumber cylindernumber symboling

# %%
# we need to convert all the data into numeric form to build regression model. to convert categorical data to numeric form
# we will use dummy encoding.. dummy encoding will create features by the name of categorical variable levels
# doornumber and cylinder number have some levels for which names are same. lets change these before dummy encoding

# %%
master_copy7=master

# %%
# create dictionary for doornumber and apply to the feature
doornumber_dict = { 'two':'twodoor', 'four': 'fourdoor' }
master['doornumber'] = master['doornumber'].map(doornumber_dict)

# %%
# create dictionary for cylindernumber and apply to the feature
cylindernumber_dict = { 'four':'four_cylinder', 'six':'six_cylinder', 'five':'five_cylinder', 'three':'three_cylinder', 'twelve':'twelve_cylinder', 'two':'two_cylinder', 'eight':'eight_cylinder' }
master['cylindernumber'] = master['cylindernumber'].map(cylindernumber_dict)

# %%
# create dictionary for symboling and apply to the feature
symboling_dict = { 0:'symbol_0', 1: 'symbol_1',2:'symbol_2',3:'symbol_3',-1:'symbol_-1',-2:'symbol_-2' }
master['symboling'] = master['symboling'].map(symboling_dict)

# %%
master.head()
# Out:
#    car_ID symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1  symbol_3      gas        std    twodoor  convertible        rwd
# 1       2  symbol_3      gas        std    twodoor  convertible        rwd
# 2       3  symbol_1      gas        std    twodoor    hatchback        rwd
# 3       4  symbol_2      gas        std   fourdoor        sedan        fwd
# 4       5  symbol_2      gas        std   fourdoor        sedan        4wd
#
#   enginelocation  wheelbase  carlength        ...          stroke  \
# 0          front       88.6      168.8        ...            2.68
# 1          front       88.6      168.8        ...            2.68
# 2          front       94.5      171.2        ...            3.47
# 3          front       99.8      176.6        ...            3.40
# 4          front       99.4      176.6        ...            3.40
#
#    compressionratio  horsepower peakrpm citympg  highwaympg    price  \
# ...

# %%
# now perform dummy encoding for categorical variables

# %%
fueltypes = pd.get_dummies(master['fueltype'], drop_first=True)
master=pd.concat([master, fueltypes], axis=1)

# %%
aspirations = pd.get_dummies(master['aspiration'], drop_first=True)
master=pd.concat([master, aspirations], axis=1)

# %%
doornumbers = pd.get_dummies(master['doornumber'], drop_first=True)
master=pd.concat([master, doornumbers], axis=1)

# %%
carbodies = pd.get_dummies(master['carbody'], drop_first=True)
master=pd.concat([master, carbodies], axis=1)

# %%
drivewheels = pd.get_dummies(master['drivewheel'], drop_first=True)
master=pd.concat([master, drivewheels], axis=1)

# %%
enginelocations = pd.get_dummies(master['enginelocation'], drop_first=True)
master=pd.concat([master, enginelocations], axis=1)

# %%
enginetypes = pd.get_dummies(master['enginetype'], drop_first=True)
master=pd.concat([master, enginetypes], axis=1)

# %%
cylindernumbers = pd.get_dummies(master['cylindernumber'], drop_first=True)
master=pd.concat([master, cylindernumbers], axis=1)

# %%
fuelsystems = pd.get_dummies(master['fuelsystem'], drop_first=True)
master=pd.concat([master, fuelsystems], axis=1)

# %%
symbols = pd.get_dummies(master['symboling'], drop_first=True)
master=pd.concat([master, symbols], axis=1)

# %%
master.head()
# Out:
#    car_ID symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1  symbol_3      gas        std    twodoor  convertible        rwd
# 1       2  symbol_3      gas        std    twodoor  convertible        rwd
# 2       3  symbol_1      gas        std    twodoor    hatchback        rwd
# 3       4  symbol_2      gas        std   fourdoor        sedan        fwd
# 4       5  symbol_2      gas        std   fourdoor        sedan        4wd
#
#   enginelocation  wheelbase  carlength    ...     idi  mfi  mpfi spdi spfi  \
# 0          front       88.6      168.8    ...       0    0     1    0    0
# 1          front       88.6      168.8    ...       0    0     1    0    0
# 2          front       94.5      171.2    ...       0    0     1    0    0
# 3          front       99.8      176.6    ...       0    0     1    0    0
# 4          front       99.4      176.6    ...       0    0     1    0    0
#
#    symbol_-2 symbol_0  symbol_1  symbol_2  symbol_3
# ...

# %%
master_copy8=master

# %%
master.drop(['fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation','enginetype','cylindernumber','fuelsystem','symboling','companyType'],axis=1,inplace=True)

# %%
master.drop(['carCompany'],axis=1, inplace=True)

# %%
######## MODEL BUILDING #############

# %%
# Bottom up approach

# %%
from sklearn.model_selection import train_test_split

np.random.seed(0)

master_train, master_test = train_test_split(master, train_size=0.7, test_size=0.3)

# %%
# SCALING THE DATA
# since we have many categorical variables - it is better to use Min Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# scale only numeric variables

# %%
master_train.dtypes
# Out:
# car_ID                 int64
# wheelbase            float64
# carlength            float64
# carwidth             float64
# carheight            float64
# curbweight             int64
# enginesize             int64
# boreratio            float64
# stroke               float64
# compressionratio     float64
# horsepower             int64
# peakrpm                int64
# citympg                int64
# highwaympg             int64
# price                float64
# low_price_company      uint8
# gas                    uint8
# turbo                  uint8
# twodoor                uint8
# hardtop                uint8
# hatchback              uint8
# sedan                  uint8
# wagon                  uint8
# fwd                    uint8
# rwd                    uint8
# rear                   uint8
# dohcv                  uint8
# l                      uint8
# ohc                    uint8
# ohcf                   uint8
# ohcv                   uint8
# rotor                  uint8
# ...

# %%
num_vars= master_train.iloc[:, (np.where((master_train.dtypes == np.int64) | (master_train.dtypes == np.float64)))[0]].columns
num_vars
# Out:
# Index(['car_ID', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# remove car_ID from numeric_vars
list_num_vars=list(set(num_vars)-set(['car_ID']))
list_num_vars
# Out:
# ['highwaympg',
#  'carlength',
#  'curbweight',
#  'boreratio',
#  'stroke',
#  'citympg',
#  'peakrpm',
#  'carheight',
#  'horsepower',
#  'compressionratio',
#  'enginesize',
#  'carwidth',
#  'price',
#  'wheelbase']

# %%
# apply scaler to dataframe

# %%
master_train_copy=master_train

# %%
master_train[list_num_vars]=scaler.fit_transform(master_train[list_num_vars])
# Out:
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
master_train.head()
# Out:
#      car_ID  wheelbase  carlength  carwidth  carheight  curbweight  \
# 120     121   0.257246   0.230909  0.190476   0.233333    0.065866
# 19       20   0.286232   0.205455  0.171429   0.350000    0.024477
# 158     159   0.329710   0.394545  0.247619   0.433333    0.202937
# 97       98   0.286232   0.465455  0.190476   0.475000    0.097018
# 54       55   0.235507   0.403636  0.228571   0.525000    0.058300
#
#      enginesize  boreratio    stroke  compressionratio    ...     idi  mfi  \
# 120    0.078125   0.230159  0.525253           0.15000    ...       0    0
# 19     0.078125   0.277778  0.464646           0.16250    ...       0    0
# 158    0.156250   0.468254  0.585859           0.96875    ...       1    0
# 97     0.105469   0.373016  0.555556           0.15000    ...       0    0
# 54     0.082031   0.317460  0.484848           0.12500    ...       0    0
#
#      mpfi  spdi  spfi  symbol_-2  symbol_0  symbol_1  symbol_2  symbol_3
# ...

# %%
############ MODEL FORMATION ############

# %%
############## APPROACH -1 Bottom up ######################

# %%
selected_features=list(master_train.columns)

# %%
#master_train1=master_train[selected_features]

# %%
# form correlation matrix of all the features in master_train1

# %%
correlation_matrix1=master_train.corr()
correlation_matrix1
# Out:
#                      car_ID  wheelbase  carlength  carwidth  carheight  \
# car_ID             1.000000   0.218168   0.232854  0.151307   0.288373
# wheelbase          0.218168   1.000000   0.868926  0.783204   0.521401
# carlength          0.232854   0.868926   1.000000  0.815860   0.396625
# carwidth           0.151307   0.783204   0.815860  1.000000   0.161406
# carheight          0.288373   0.521401   0.396625  0.161406   1.000000
# curbweight         0.130372   0.767039   0.872198  0.835863   0.209499
# enginesize         0.000509   0.509353   0.663402  0.697286  -0.055579
# boreratio          0.268101   0.494105   0.616489  0.595539   0.133384
# stroke            -0.111723   0.152328   0.123493  0.160224  -0.077924
# compressionratio   0.232460   0.189323   0.106209  0.096433   0.201478
# horsepower        -0.011742   0.340068   0.533957  0.665382  -0.185371
# peakrpm           -0.211879  -0.312663  -0.263151 -0.129723  -0.290670
# ...

# %%
# uncomment below to export to csv
#correlation_matrix1.to_csv('correlation_matrix.csv')

# %%
# we have highest correlation of horsepower with price 0.8465

# %%
# lets start model with price vs horsepower

# %%
import statsmodels.api as sm

# %%
master_train_copy1=master_train

# %%
y_train=master_train.pop('price')

# %%
X_train=master_train

# %%
# horsepower has highest correlation , create model horsepower vs price

# %%
################## MODEL 1 ###################

X_train_lm = sm.add_constant(X_train['horsepower'])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.715
# Method:                 Least Squares   F-statistic:                     341.4
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           8.76e-39
# Time:                        22:53:22   Log-Likelihood:                 100.08
# No. Observations:                 137   AIC:                            -196.2
# Df Residuals:                     135   BIC:                            -190.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0032      0.016     -0.199      0.843      -0.035       0.029
# ...

# %%
# lets add second highest correlated variable enginesize to above model and make another model

# %%
################## MODEL 2 ###################

X_train_lm = sm.add_constant(X_train[['horsepower','enginesize']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     232.8
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.53e-44
# Time:                        22:53:27   Log-Likelihood:                 116.34
# No. Observations:                 137   AIC:                            -226.7
# Df Residuals:                     134   BIC:                            -217.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0406      0.016     -2.580      0.011      -0.072      -0.009
# ...

# %%
# model statistics: adjusted R squared, AIC, and BIC improved whereas F statistic decreased

# %%
# Let's create model enginesize vs price (drop horsepower)

# %%
################## MODEL 3 ###################

X_train_lm = sm.add_constant(X_train[['enginesize']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.710
# Model:                            OLS   Adj. R-squared:                  0.708
# Method:                 Least Squares   F-statistic:                     330.1
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           4.45e-38
# Time:                        22:53:32   Log-Likelihood:                 98.436
# No. Observations:                 137   AIC:                            -192.9
# Df Residuals:                     135   BIC:                            -187.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0343      0.018     -1.927      0.056      -0.070       0.001
# ...

# %%
# among 1,2,3 Adjusted R squared for Model 2 is best.. let us select that model and add more features

# %%
################# MODEL 4 ##################

# add curbweight to Model 2
X_train_lm = sm.add_constant(X_train[['horsepower','enginesize','curbweight']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.793
# Method:                 Least Squares   F-statistic:                     174.6
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           6.19e-46
# Time:                        22:53:37   Log-Likelihood:                 123.11
# No. Observations:                 137   AIC:                            -238.2
# Df Residuals:                     133   BIC:                            -226.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0536      0.015     -3.475      0.001      -0.084      -0.023
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# lets check vif
vif = pd.DataFrame()
feature_list=['horsepower','enginesize','curbweight']
vif['Features'] = feature_list
vif['VIF'] = [variance_inflation_factor(X_train[feature_list].values, i) for i in range (X_train[feature_list].shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values( by = 'VIF', ascending = False)
vif
# Out:
#      Features    VIF
# 1  enginesize  15.54
# 2  curbweight  10.32
# 0  horsepower   8.88

# %%
master_train_copy2=master_train

# %%
############# MODEL 5  ##########

# add low_price_company (correlation :-0.75) to above model and check

X_train_lm = sm.add_constant(X_train[['horsepower','enginesize','curbweight','low_price_company']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                     303.8
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.58e-65
# Time:                        22:53:46   Log-Likelihood:                 172.83
# No. Observations:                 137   AIC:                            -335.7
# Df Residuals:                     132   BIC:                            -321.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# adjusted R squared and BIC have both improved

# %%
# significance of enginesize has decreased on adding low_price_company

# %%
# lets check vif
vif = pd.DataFrame()
feature_list=['horsepower','enginesize','curbweight','low_price_company']
vif['Features'] = feature_list
vif['VIF'] = [variance_inflation_factor(X_train[feature_list].values, i) for i in range (X_train[feature_list].shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values( by = 'VIF', ascending = False)
vif
# Out:
#             Features    VIF
# 1         enginesize  15.54
# 2         curbweight  11.33
# 0         horsepower   8.89
# 3  low_price_company   2.01

# %%
# remove enginesize and check
############# MODEL 6##########

X_train_lm = sm.add_constant(X_train[['horsepower','curbweight','low_price_company']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                     404.7
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.19e-66
# Time:                        22:53:59   Log-Likelihood:                 172.30
# No. Observations:                 137   AIC:                            -336.6
# Df Residuals:                     133   BIC:                            -324.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# add curbweight and remove horsepower and check
############# MODEL 7##########

X_train_lm = sm.add_constant(X_train[['curbweight','enginesize','low_price_company']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     296.7
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.04e-58
# Time:                        22:54:04   Log-Likelihood:                 153.46
# No. Observations:                 137   AIC:                            -298.9
# Df Residuals:                     133   BIC:                            -287.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# from models created till now Model 6 (best adjusted R squared and BIC) looks good.. lets try to improve further

# %%
# let us add next highly correlated variable : citympg(-0.73)

############# MODEL 8##########

X_train_lm = sm.add_constant(X_train[['horsepower','curbweight','low_price_company','citympg']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                     302.5
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.05e-65
# Time:                        22:54:13   Log-Likelihood:                 172.56
# No. Observations:                 137   AIC:                            -335.1
# Df Residuals:                     132   BIC:                            -320.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# citympg is not significant .. remove it
# add next highly correlated variable : carwidth( correlation:0.71 with price) 
################ MODEL 9 ##################
X_train_lm = sm.add_constant(X_train[['horsepower','curbweight','low_price_company','carwidth']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     318.4
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           9.63e-67
# Time:                        22:54:17   Log-Likelihood:                 175.73
# No. Observations:                 137   AIC:                            -341.5
# Df Residuals:                     132   BIC:                            -326.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
################ MODEL 10 ##################
# add next highly correlated variable : highwaympg( correlation:-0.7 with price) 
X_train_lm = sm.add_constant(X_train[['horsepower','curbweight','low_price_company','highwaympg']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                     301.8
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.32e-65
# Time:                        22:54:30   Log-Likelihood:                 172.42
# No. Observations:                 137   AIC:                            -334.8
# Df Residuals:                     132   BIC:                            -320.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove highwaympg

# %%
################ MODEL 11 ##################
# add next highly correlated variable : four_cylinder ( correlation:-0.67 with price) 
X_train_lm = sm.add_constant(X_train[['horsepower','curbweight','low_price_company','four_cylinder']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.900
# Method:                 Least Squares   F-statistic:                     306.7
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           8.95e-66
# Time:                        22:54:36   Log-Likelihood:                 173.42
# No. Observations:                 137   AIC:                            -336.8
# Df Residuals:                     132   BIC:                            -322.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
################ MODEL 12 ##################

# remove four_cylinder
# add next highly correlated variable : rwd ( correlation:0.65 with price) 
X_train_lm = sm.add_constant(X_train[['horsepower','curbweight','low_price_company','rwd']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.900
# Method:                 Least Squares   F-statistic:                     308.5
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           6.33e-66
# Time:                        22:54:40   Log-Likelihood:                 173.78
# No. Observations:                 137   AIC:                            -337.6
# Df Residuals:                     132   BIC:                            -323.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove rwd

# go back to model 6

X_train_lm = sm.add_constant(X_train[['horsepower','curbweight','low_price_company']])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                     404.7
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.19e-66
# Time:                        22:54:44   Log-Likelihood:                 172.30
# No. Observations:                 137   AIC:                            -336.6
# Df Residuals:                     133   BIC:                            -324.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# Model 6 has better statistics than other models

# %%
##### RESIDUAL ANALYSIS of train data ############

# %%
y_train_price_model_6 = lr_all.predict(X_train_lm)

# %%
# Plot histogram of the error terms

fig=plt.figure()
sns.distplot((y_train-y_train_price_model_6), bins=20)
fig.suptitle("Error terms", fontsize=20)
plt.xlabel("Errors",fontsize=18)
# Out:
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,0,'Errors')

# %%
################ Lets try Top Down Approach and see if we can make a better model

# %%
######################################### TOP DOWN APPROACH TO MODEL CREATION ##################################

# %%
len(X_train.columns)
# Out:
# 49

# %%
# There are too many features to proceed manually and eliminate one by one

# %%
# Top down approach
# take all features and perform following steps
## 1. calculate vif
# 2. if any vif is greater than 5, eliminate the variable and update the feature list, else goto 4 with final feature list
# 3. Repeat 1 and 2
# 4. further eliminate features based on significance level (p-value)
# 5. Choose different combinations of features to increase R squared value and F statistic and reduce BIC

# %%
# to perform steps 1 to 3, check_vif function is created

# check_vif is a function that does the following
# 1. calculate vif
# 2. if any vif is greater than 5 and maxtimes(function parameter) is greater than zero, eliminate the variable and 
# update the feature list. imaxtimes is equal to zero, print just calculated vifs and goto 4
# 3. Repeat 1 and 2
# 4. the number of times loop inside the function runs is specified by the user through parameter: maxtimes

#col = X_train.columns
X_train_for_rfe=X_train
def check_vif(X_train, maxtimes):
    #y_train=df_train.pop('price')
    #X_train=df_train
    col=X_train.columns
    column_list=list(col)
    vif_rfe = pd.DataFrame()
    X_train=X_train[column_list]
    vif_rfe['Features'] = X_train.columns

    vif_rfe['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range (X_train.shape[1])]
    vif_rfe['VIF'] = round(vif_rfe['VIF'],2)
    vif_rfe = vif_rfe.sort_values( by = 'VIF', ascending = False)
    #vif_rfe
    vif_rfe = vif_rfe.replace([np.inf, -np.inf], np.nan)
    
    
    multicollinearity_detected = False
    #
    if vif_rfe.iloc[0].VIF>=5 | np.isnan(vif_rfe.iloc[0].VIF):
        #print('inside if')
        multicollinearity_detected=True
    
    #maxtimes=1
    #print(maxtimes)
    while(maxtimes>0 & multicollinearity_detected):
        #print('inside while')
        column_list.remove(vif_rfe.iloc[0].Features)
        X_train_new=pd.DataFrame()
        X_train_new=X_train[column_list]
        X_train=pd.DataFrame()
        X_train=X_train_new
        
        vif_rfe = pd.DataFrame()
        #X_train_new=X_train[col_list]
        vif_rfe['Features'] = X_train.columns

        vif_rfe['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range (X_train_new.shape[1])]
        vif_rfe['VIF'] = round(vif_rfe['VIF'],2)
        vif_rfe = vif_rfe.sort_values( by = 'VIF', ascending = False)
        
        if vif_rfe.iloc[0].VIF>=5:
            multicollinearity_detected=True
        
        maxtimes=maxtimes-1
    vif_func=vif_rfe    
    return vif_func

# %%
vif_func=check_vif(X_train,15)
# Out:
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\statsmodels\stats\outliers_influence.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1543: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1545: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss

# %%
vif_func
# Out:
#             Features    VIF
# 1           carwidth  19.86
# 15               ohc  17.86
# 10               fwd  17.76
# 2          carheight  16.46
# 11               rwd  16.16
# 26              mpfi  15.10
# 4            peakrpm  10.26
# 23              2bbl   8.59
# 0             car_ID   7.62
# 31          symbol_1   7.47
# 6            twodoor   6.86
# 3   compressionratio   6.63
# 30          symbol_0   5.96
# 14                 l   5.05
# 33          symbol_3   5.01
# 32          symbol_2   4.15
# 19      six_cylinder   4.02
# 8          hatchback   3.47
# 16              ohcf   3.34
# 27              spdi   2.81
# 12              rear   2.74
# 22      two_cylinder   2.49
# 17              ohcv   2.43
# 5              turbo   2.41
# 24              4bbl   2.24
# 21   twelve_cylinder   1.98
# 9              wagon   1.91
# 13             dohcv   1.68
# 7            hardtop   1.59
# 18     five_cylinder   1.56
# 25               mfi   1.48
# 28              spfi   1.32
# ...

# %%
# we still have vifs greater than 5. But we have already lost important variables (as per business understanding) like curbweight,
# enginesize, horsepower
# the features that had high correlation with price have been lost
# That means we should not focus on vif alone for feature elimination

# %%
# Let us go for automated approach (RFE) and reduce the number of variables to around 10 and then proceed with manual elimination
# in Manual Elimination we will eliminate features on the basis of 
# 1. VIF
# 2. p-VALUE

# %%
# apply RFE

# %%
X_train_for_rfe=X_train

# %%
# Importing RFE and Linear Regression

from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# number of output variables equal to 35

lm = LinearRegression()
lm.fit(X_train_for_rfe, y_train)
rfe = RFE(lm, 35)
rfe = rfe.fit(X_train_for_rfe , y_train)

# %%
# select columns for which rfe support is True
col = X_train_for_rfe.columns[rfe.support_]
col
# Out:
# Index(['carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio',
#        'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg',
#        'highwaympg', 'low_price_company', 'gas', 'turbo', 'hardtop',
#        'hatchback', 'sedan', 'wagon', 'rwd', 'rear', 'dohcv', 'ohc', 'ohcf',
#        'ohcv', 'rotor', 'five_cylinder', 'four_cylinder', 'six_cylinder',
#        'twelve_cylinder', 'two_cylinder', '2bbl', '4bbl', 'idi', 'mpfi',
#        'spfi'],
#       dtype='object')

# %%
X_train_lm = sm.add_constant(X_train[col])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     91.36
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.53e-62
# Time:                        23:00:30   Log-Likelihood:                 244.63
# No. Observations:                 137   AIC:                            -423.3
# Df Residuals:                     104   BIC:                            -326.9
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# spfi has high p-value of 0.59, eliminate this feature

# %%
col_list = list(set(col)-set(['spfi']))

# %%
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     94.95
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.79e-63
# Time:                        23:01:56   Log-Likelihood:                 244.44
# No. Observations:                 137   AIC:                            -424.9
# Df Residuals:                     105   BIC:                            -331.4
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove 4 bbl
col_list.remove('4bbl')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     98.55
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.29e-64
# Time:                        23:02:01   Log-Likelihood:                 244.10
# No. Observations:                 137   AIC:                            -426.2
# Df Residuals:                     106   BIC:                            -335.7
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove highwaympg
col_list.remove('highwaympg')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     102.4
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.85e-65
# Time:                        23:02:08   Log-Likelihood:                 243.79
# No. Observations:                 137   AIC:                            -427.6
# Df Residuals:                     107   BIC:                            -340.0
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove dohcv
col_list.remove('dohcv')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     102.4
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.85e-65
# Time:                        23:02:13   Log-Likelihood:                 243.79
# No. Observations:                 137   AIC:                            -427.6
# Df Residuals:                     107   BIC:                            -340.0
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove five_cylinder
col_list.remove('five_cylinder')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     106.3
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           3.90e-66
# Time:                        23:02:18   Log-Likelihood:                 243.33
# No. Observations:                 137   AIC:                            -428.7
# Df Residuals:                     108   BIC:                            -344.0
# Df Model:                          28
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove six_cylinder
col_list.remove('six_cylinder')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     111.1
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           3.99e-67
# Time:                        23:02:22   Log-Likelihood:                 243.22
# No. Observations:                 137   AIC:                            -430.4
# Df Residuals:                     109   BIC:                            -348.7
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove idi
col_list.remove('idi')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     111.1
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           3.99e-67
# Time:                        23:02:35   Log-Likelihood:                 243.22
# No. Observations:                 137   AIC:                            -430.4
# Df Residuals:                     109   BIC:                            -348.7
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove citympg
col_list.remove('citympg')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     115.1
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           6.80e-68
# Time:                        23:02:40   Log-Likelihood:                 242.44
# No. Observations:                 137   AIC:                            -430.9
# Df Residuals:                     110   BIC:                            -352.0
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# remove gas
col_list.remove('gas')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     119.6
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.03e-68
# Time:                        23:02:48   Log-Likelihood:                 241.79
# No. Observations:                 137   AIC:                            -431.6
# Df Residuals:                     111   BIC:                            -355.7
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# let us check vif 
# calling check_vif with maxtimes =0, only returns vif of the X_train without elminating any feature
vif=check_vif(X_train[col_list],0)
vif
# Out:
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\statsmodels\stats\outliers_influence.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#              Features     VIF
# 2               rotor     NaN
# 10       two_cylinder     NaN
# 16         enginesize  124.70
# 3              stroke   65.03
# 11          boreratio   60.56
# 8          curbweight   56.12
# 20      four_cylinder   42.64
# 21         horsepower   34.01
# 24           carwidth   28.39
# 17              sedan   25.26
# 19  low_price_company   24.07
# 9           hatchback   16.45
# 15          carheight   16.16
# 6             peakrpm   12.15
# 18                ohc   10.78
# 25              wagon    9.55
# 22               mpfi    7.74
# 5                2bbl    5.51
# 12                rwd    5.42
# 0     twelve_cylinder    4.44
# 7                ohcf    3.79
# 23   compressionratio    3.46
# 1               turbo    3.17
# 4                rear    2.56
# ...

# %%
# remove feature with highest vif
# this can be done by calling check_vif with maxtimes=1
vif=check_vif(X_train[col_list],1)
vif
# Out:
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\statsmodels\stats\outliers_influence.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#              Features     VIF
# 15         enginesize  124.70
# 2              stroke   65.03
# 10          boreratio   60.56
# 7          curbweight   56.12
# 19      four_cylinder   42.64
# 20         horsepower   34.01
# 23           carwidth   28.39
# 16              sedan   25.26
# 18  low_price_company   24.07
# 8           hatchback   16.45
# 14          carheight   16.16
# 5             peakrpm   12.15
# 17                ohc   10.78
# 24              wagon    9.55
# 21               mpfi    7.74
# 4                2bbl    5.51
# 11                rwd    5.42
# 0     twelve_cylinder    4.44
# 6                ohcf    3.79
# 9        two_cylinder    3.62
# 22   compressionratio    3.46
# 1               turbo    3.17
# 3                rear    2.56
# 12               ohcv    2.43
# ...

# %%
# remove two_cylinder from feature list

col_list.remove('two_cylinder')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     119.6
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.03e-68
# Time:                        23:03:05   Log-Likelihood:                 241.79
# No. Observations:                 137   AIC:                            -431.6
# Df Residuals:                     111   BIC:                            -355.7
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# check vif
vif=check_vif(X_train[col_list],1)
vif
# Out:
#              Features    VIF
# 10          boreratio  46.22
# 8          curbweight  38.78
# 18      four_cylinder  34.31
# 19         horsepower  29.27
# 22           carwidth  27.84
# 3              stroke  26.67
# 15              sedan  25.21
# 17  low_price_company  22.66
# 9           hatchback  16.39
# 14          carheight  15.94
# 6             peakrpm  11.77
# 16                ohc  10.77
# 23              wagon   9.42
# 20               mpfi   7.74
# 11                rwd   5.32
# 5                2bbl   5.28
# 7                ohcf   3.69
# 21   compressionratio   3.39
# 4                rear   2.54
# 1               turbo   2.51
# 12               ohcv   2.27
# 0     twelve_cylinder   2.17
# 13            hardtop   1.98
# 2               rotor   1.84

# %%
#eliminate enginesize


col_list.remove('enginesize')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     106.9
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           5.03e-66
# Time:                        23:03:13   Log-Likelihood:                 231.16
# No. Observations:                 137   AIC:                            -412.3
# Df Residuals:                     112   BIC:                            -339.3
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
##eliminate stroke


col_list.remove('stroke')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     112.4
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           5.18e-67
# Time:                        23:03:17   Log-Likelihood:                 231.04
# No. Observations:                 137   AIC:                            -414.1
# Df Residuals:                     113   BIC:                            -344.0
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#eliminate twelve_cylinder


col_list.remove('twelve_cylinder')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     118.1
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           5.76e-68
# Time:                        23:03:21   Log-Likelihood:                 230.79
# No. Observations:                 137   AIC:                            -415.6
# Df Residuals:                     114   BIC:                            -348.4
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#eliminate four_cylinder


col_list.remove('four_cylinder')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     124.7
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           5.18e-69
# Time:                        23:03:24   Log-Likelihood:                 230.77
# No. Observations:                 137   AIC:                            -417.5
# Df Residuals:                     115   BIC:                            -353.3
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#eliminate ohcv


col_list.remove('ohcv')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     131.7
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           5.35e-70
# Time:                        23:03:28   Log-Likelihood:                 230.55
# No. Observations:                 137   AIC:                            -419.1
# Df Residuals:                     116   BIC:                            -357.8
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#eliminate turbo


col_list.remove('turbo')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     138.8
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           6.64e-71
# Time:                        23:03:33   Log-Likelihood:                 230.07
# No. Observations:                 137   AIC:                            -420.1
# Df Residuals:                     117   BIC:                            -361.7
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#eliminate carheight


col_list.remove('carheight')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     146.3
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           9.43e-72
# Time:                        23:03:37   Log-Likelihood:                 229.42
# No. Observations:                 137   AIC:                            -420.8
# Df Residuals:                     118   BIC:                            -365.4
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#eliminate compressionratio


col_list.remove('compressionratio')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     152.9
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.46e-72
# Time:                        23:03:43   Log-Likelihood:                 228.03
# No. Observations:                 137   AIC:                            -420.1
# Df Residuals:                     119   BIC:                            -367.5
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#eliminate 2bbl


col_list.remove('2bbl')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     162.6
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.87e-73
# Time:                        23:03:46   Log-Likelihood:                 227.55
# No. Observations:                 137   AIC:                            -421.1
# Df Residuals:                     120   BIC:                            -371.5
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#eliminate mpfi


col_list.remove('mpfi')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     174.1
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.83e-74
# Time:                        23:03:50   Log-Likelihood:                 227.22
# No. Observations:                 137   AIC:                            -422.4
# Df Residuals:                     121   BIC:                            -375.7
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#eliminate peakrpm


col_list.remove('peakrpm')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     185.2
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           4.87e-75
# Time:                        23:03:56   Log-Likelihood:                 226.23
# No. Observations:                 137   AIC:                            -422.5
# Df Residuals:                     122   BIC:                            -378.7
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#check vif
vif=check_vif(X_train[col_list],0)
vif
# Out:
#              Features    VIF
# 3          curbweight  23.87
# 12           carwidth  23.12
# 5           boreratio  19.85
# 8               sedan  13.67
# 10  low_price_company  11.35
# 4           hatchback   9.92
# 11         horsepower   9.35
# 9                 ohc   8.31
# 13              wagon   5.13
# 6                 rwd   4.14
# 2                ohcf   3.05
# 1                rear   1.95
# 7             hardtop   1.75
# 0               rotor   1.20

# %%
#vif for curbweight is maximum and greater than 5. Remove this feature

# %%
col_list_copy=col_list

# %%
#eliminate curbweight 


col_list.remove('curbweight')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     140.6
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           3.33e-67
# Time:                        23:04:07   Log-Likelihood:                 203.05
# No. Observations:                 137   AIC:                            -378.1
# Df Residuals:                     123   BIC:                            -337.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# ohcf is not significant. Remove it
col_list.remove('ohcf')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     153.0
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           3.28e-68
# Time:                        23:04:11   Log-Likelihood:                 202.80
# No. Observations:                 137   AIC:                            -379.6
# Df Residuals:                     124   BIC:                            -341.6
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# eliminate ohc
col_list.remove('ohc')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     167.0
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           3.77e-69
# Time:                        23:04:15   Log-Likelihood:                 202.33
# No. Observations:                 137   AIC:                            -380.7
# Df Residuals:                     125   BIC:                            -345.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# eliminate rotor
col_list.remove('rotor')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     181.7
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           8.24e-70
# Time:                        23:04:19   Log-Likelihood:                 201.11
# No. Observations:                 137   AIC:                            -380.2
# Df Residuals:                     126   BIC:                            -348.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# eliminate boreratio
col_list.remove('boreratio')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     199.1
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.03e-70
# Time:                        23:04:22   Log-Likelihood:                 199.71
# No. Observations:                 137   AIC:                            -379.4
# Df Residuals:                     127   BIC:                            -350.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# check vif
vif=check_vif(X_train[col_list],0)
vif
# Out:
#             Features    VIF
# 7           carwidth  12.77
# 5  low_price_company  10.73
# 4              sedan   8.67
# 6         horsepower   7.47
# 1          hatchback   6.64
# 8              wagon   3.48
# 2                rwd   2.66
# 3            hardtop   1.50
# 0               rear   1.44

# %%
#eliminate carwidth
col_list.remove('carwidth')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     119.9
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.14e-55
# Time:                        23:04:34   Log-Likelihood:                 160.25
# No. Observations:                 137   AIC:                            -302.5
# Df Residuals:                     128   BIC:                            -276.2
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# eliminate sedan
col_list.remove('sedan')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     138.1
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           9.34e-57
# Time:                        23:04:39   Log-Likelihood:                 160.25
# No. Observations:                 137   AIC:                            -304.5
# Df Residuals:                     129   BIC:                            -281.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# eliminate wagon
col_list.remove('wagon')
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     162.4
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           7.02e-58
# Time:                        23:04:45   Log-Likelihood:                 160.25
# No. Observations:                 137   AIC:                            -306.5
# Df Residuals:                     130   BIC:                            -286.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# check vif
vif = check_vif(X_train[col_list],0)
vif
# Out:
#             Features   VIF
# 5         horsepower  3.63
# 2                rwd  2.50
# 4  low_price_company  2.14
# 1          hatchback  1.58
# 0               rear  1.36
# 3            hardtop  1.25

# %%
# now all the features are significant p-value< 0.05
# vif <5 for each feature as well

# %%
#list of independent variables for linear regression model: col_list
col_list
# Out:
# ['rear', 'hatchback', 'rwd', 'hardtop', 'low_price_company', 'horsepower']

# %%
######################### RESIDUAL ANALYSIS #################

# %%
price_predicted = lr_all.predict(X_train_lm)

# %%
# Plot histogram of the error terms

fig=plt.figure()
sns.distplot((y_train-price_predicted), bins=20)
fig.suptitle("Error terms", fontsize=20)
plt.xlabel("Errors",fontsize=18)
# Out:
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,0,'Errors')

# %%
# plot is centred around zero with  errors nearly normally distributed
# error is more towards right. It is related to the fact that the relationship between independent variables and dependent
# variable was more spread out when the value of independent variables were higher

# %%
################################ PREDICTION ####################

# %%
list_num_vars # numeric variables on which minmax scaling was applied
# Out:
# ['highwaympg',
#  'carlength',
#  'curbweight',
#  'boreratio',
#  'stroke',
#  'citympg',
#  'peakrpm',
#  'carheight',
#  'horsepower',
#  'compressionratio',
#  'enginesize',
#  'carwidth',
#  'price',
#  'wheelbase']

# %%
#features=['horsepower', 'rear', 'hardtop', 'hatchback', 'low_price_company', 'rwd']

# %%
master_test[list_num_vars] = scaler.transform(master_test[list_num_vars])
# Out:
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\gagandeep\UPGRAD\Anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Dividing into X_test and y_test
y_test=master_test.pop('price')
X_test=master_test

# %%
X_test_selected_features = X_test[col_list]

# %%
X_test_m=sm.add_constant(X_test_selected_features)

# %%
y_predict_m=lr_all.predict(X_test_m)

# %%
########## MODEL EVALUATION #####################

# %%
fig=plt.figure()
plt.scatter(y_test,y_predict_m)
fig.suptitle('y_test vs y_predicted ', fontsize=20)
plt.xlabel('ytest',fontsize=18)
plt.ylabel('y_predicted', fontsize=16)
# Out:
# Text(0,0.5,'y_predicted')

# %%
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     162.4
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           7.02e-58
# Time:                        23:06:06   Log-Likelihood:                 160.25
# No. Observations:                 137   AIC:                            -306.5
# Df Residuals:                     130   BIC:                            -286.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# Model Pridiction is fair

# %%
# Therefore TOP DOWN MODEL 
# features = ['horsepower', 'rear', 'hardtop', 'hatchback', 'low_price_company', 'rwd']

# %%
# This is better model than Bottom Up Model 6 with features: ['horsepower', 'curbweight', 'low_price_company'] 
# in Model 6 there were strong associations among features and the vifs were very high (highest one was around 15)

# %%
 # Lets check if we used only coarse tuning (RFE), how good the model would have been
# number of output variables equal to 6

lm = LinearRegression()
lm.fit(X_train_for_rfe, y_train)
rfe = RFE(lm, 6)
rfe = rfe.fit(X_train_for_rfe , y_train)

# %%
# select columns for which rfe support is True
col = X_train_for_rfe.columns[rfe.support_]
col
# Out:
# Index(['carwidth', 'curbweight', 'horsepower', 'low_price_company', 'rear',
#        'dohcv'],
#       dtype='object')

# %%
X_train_lm = sm.add_constant(X_train[col])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     315.0
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           6.96e-75
# Time:                        23:07:01   Log-Likelihood:                 201.63
# No. Observations:                 137   AIC:                            -389.3
# Df Residuals:                     130   BIC:                            -368.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# check vif
vif=check_vif(X_train[col],0)
vif
# Out:
#             Features    VIF
# 0           carwidth  19.08
# 1         curbweight  15.63
# 2         horsepower   9.00
# 3  low_price_company   3.83
# 5              dohcv   1.46
# 4               rear   1.33

# %%
# vifs are high (many are above 5). Therefore fine tuning after coarse tuning created better model than just using RFE

# %%
########## CONCLUSION  #####

# Final model is : Model TOP DOWN
# list of significant features:      ['horsepower', 'rear', 'hardtop', 'hatchback', 'low_price_company', 'rwd']

# coeffeicients can be seen from summary below
# low_price_company was created from the categorical variable : carCompany: therefore, brand of the car is important in 
# deciding price of the car
# hardtop carbody type affects the pric of car in negative, if carbody is hardtop, price of  car will reduce
# hatchback carbody type affects the pric of car in negative, if carbody is hatchback, price of  car will reduce
# rear was initially a level in the categorical vraible enginelocation. if engine is in the rear of the car its price is more
# compared to fron located engine
# for drivewheel:'rwd' price will be higher than other categories of drivewheel

# %%
# the car design features on which Geely auto should focus are: 
#  'horsepower', 'rear', 'carbody', 'drivewheel'
# order of significance (based on coefficient values in the TOP DOWN Linear Regression Model)

# %%
# Final model summary shown once again below

# %%
X_train_lm = sm.add_constant(X_train[col_list])
lr_all = sm.OLS(y_train, X_train_lm).fit()
lr_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     162.4
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           7.02e-58
# Time:                        23:08:27   Log-Likelihood:                 160.25
# No. Observations:                 137   AIC:                            -306.5
# Df Residuals:                     130   BIC:                            -286.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
################## Assignment Ends ############
